# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenhuuduong20062002/NguyenHuuDuong20104025/blob/main/Baitap2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openpyxl import Workbook
wb= Workbook()
sheet=wb.active
sheet['A1']='Nguyen Huu Duong'
sheet['B1']=20104025
sheet['A2']='Le Thi B'
sheet['B2']=20104002
wb.save('test.xlsx')

# %%
import openpyxl
wb=openpyxl.load_workbook('test.xlsx')
sheet=wb.active
t1=sheet['A1']
t2=sheet['B1']
#t3=sheet.cell(row=2,column=1)
#t4=sheet.cell(row=2,column=2)
print(t1.value,t2.value,t3.value,t4.value)
#print(t3.value,t4.value)
# Out:
# Nguyen Huu Duong 20104025 Le Thi B 20104002

# %%
import openpyxl
my_wb = openpyxl.Workbook()
my_sheet = my_wb.active
c1 = my_sheet.cell(row = 1, column = 1)
c1.value = "Nguyen Huu Duong"
c2 = my_sheet.cell(row = 1, column = 2)
c2.value = "VTTT"
c3 = my_sheet['A2']
c3.value = "DepTrai"
c4 = my_sheet['B2']
c4.value = "Socute"
my_wb.create_sheet(index = 1, title ="Sobad")
my_wb.save('D:\Baitap2.xlsx')
my_cell_obj = my_sheet_obj.cell(row = 1, column = 1)
print(my_cell_obj.value)
# Out:
# None

# %%
import openpyxl
my_wb = openpyxl.Workbook()
my_sheet = my_wb.active
my_wb.create_sheet(index = 1, title ="Sobad")
my_wb.save("D:\Baitap2.xlsx")

# %%
import openpyxl
my_path = 'D:\Baitap2.xlsx'
my_wb_obj = openpyxl.load_workbook(my_path)
my_sheet_obj = my_wb_obj.active
print(my_sheet_obj.max_row)
my_cell_obj = my_sheet_obj.cell(row = 1, column = 1)
print(my_cell_obj.value)
# Out:
# 2
# Nguyen Huu Duong

# %%
import openpyxl
my_path = "D:\Baitap2.xlsx"
my_wb_obj = openpyxl.load_workbook(my_path)
my_sheet_obj = my_wb_obj.active
print(my_sheet_obj.max_column)
# Out:
# 2

# %%
my_wb_obj = openpyxl.load_workbook(my_path)
my_sheet_obj = my_wb_obj.active
my_max_col = my_sheet_obj.max_column
for i in range(1, my_max_col + 1):
	my_cell_obj = my_sheet_obj.cell(row = 1, column = i)
	print(my_cell_obj.value)
# Out:
# Nguyen Huu Duong
# VTTT

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(6)
y = x + 1
plt.plot(x,y,'o--')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(6)
y = x + 1
plt.plot(x,y,'o-')
plt.plot(x,-y,'o--')
plt.title('y=x và y=-x')
plt.xlabel('x')
plt.ylabel('y')
#plt.axis('off')
plt.grid('on')
plt.show()

# %%
N=16
x=np.linspace(0,15,16)
y=x
plt.plot(x,y,'o--')
plt.axis('off')
plt.show()

# %%
from numpy.core.function_base import logspace
N=16
x=np.linspace(0,15,16)
y=np.logspace(0.1,2,16)
plt.plot(x,y,'--o')

# %%
x=[4,5,3,1,6,7]
plt.plot(x)
plt.show()

# %%
x=np.arange(25)
plt.plot(x)
plt.show()

# %%
x=np.arange(25)
plt.plot(x,x**3 + 1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.arange(7)
plt.plot(x,-x**2,'--')
plt.plot(x,-x**3,'--')
plt.plot(x,-2*x,':')
plt.plot(x,-2**x)
plt.grid('on')
plt.title('Hinh1')
plt.savefig('Hinh1_ttnt.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.arange(3)
plt.subplots_adjust(wspace=0.2,hspace=0.4)
plt.subplot(3,2,1)
plt.plot(x,-x**2, color='r')
plt.subplot(3,2,2)
plt.plot(x,-x**3, color='b')
plt.subplot(3,2,3)
plt.plot(x,-2*x, color = 'r')
plt.subplot(3,2,4)
plt.plot(x,-2**x,'--')
plt.show()

# %%
plt.axis([0,100,0,10])
plt.scatter(30,4,s=2000, color='g', alpha=1)
plt.scatter(50,6,s=2000, color='r', alpha=.5)
plt.scatter(70,8,s=2000, color ='b', alpha=.1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot([1,2],[3,4],linewidth=5, color='r')
plt.text(1.5,3,'TRAIDEP')
plt.arrow(1,3,1,1, head_length=4, head_width = 2, color ='b')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.arrow(30,30,0,-30, head_length=4, head_width = 2, color ='b')

# %%
x=np.arange(4)
y=np.random.rand(4)
plt.bar(x,y)
plt.show()

# %%
y=np.random.rand(3,4)
plt.bar(x + 0, y[0], color = 'b', width=0.25)
plt.bar(x + 0.25, y[1], color = 'r', width=0.25)
plt.bar(x + 0.5, y[2], color = 'g', width=0.25)
plt.show()

# %%
x=np.arange(4)
y=np.random.rand(4)
plt.barh(x,y)
plt.show()

# %%
N=1000
x=np.random.rand(N)
y=np.random.rand(N)
colors=np.random.rand(N)
size = 20
plt.scatter(x,y,s=size, c=colors, alpha=1)
plt.show()
